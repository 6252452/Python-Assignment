# %%
fname = input("Input your First Name : ")
lname = input("Input your Last Name : ")
print ("Hello  " + lname + " " + fname)
# Out:
# Input your First Name : Syed Farman
# Input your Last Name : Hussain
# Hello  Hussain Syed Farman
